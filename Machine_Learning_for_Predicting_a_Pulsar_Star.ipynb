# %% [markdown]
# <a href="https://colab.research.google.com/github/ZerXXX0/machine-learning-for-predicting-pulsar-star/blob/main/Machine_Learning_for_Predicting_a_Pulsar_Star.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
url = 'https://raw.githubusercontent.com/ZerXXX0/machine-learning-for-predicting-pulsar-star/main/pulsar_data_test.csv'
data = pd.read_csv(url,index_col = 0)
data
# Out:
#                                   Standard deviation of the integrated profile  \
#  Mean of the integrated profile
# 116.906250                                                           48.920605
# 75.585938                                                            34.386254
# 103.273438                                                           46.996628
# 101.078125                                                           48.587487
# 113.226562                                                           48.608804
# ...                                                                        ...
# 116.531250                                                           51.140269
# 114.976562                                                           53.783052
# 136.171875                                                           48.924385
# 106.500000                                                           49.066122
# ...

# %%
df = pd.DataFrame(data)
print(df)
print(df.describe())
print(df.info())
# Out:
#                                   Standard deviation of the integrated profile  \
#  Mean of the integrated profile
# 116.906250                                                           48.920605
# 75.585938                                                            34.386254
# 103.273438                                                           46.996628
# 101.078125                                                           48.587487
# 113.226562                                                           48.608804
# ...                                                                        ...
# 116.531250                                                           51.140269
# 114.976562                                                           53.783052
# 136.171875                                                           48.924385
# 106.500000                                                           49.066122
# ...

# %%
sns.pairplot(df, hue='target_class')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1134: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_data.insert(0, var, comp_col)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-44a203428efd> in <cell line: 1>()
# ----> 1 sns.pairplot(df, hue='target_class')
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2146         diag_kws.setdefault("fill", True)
#    2147         diag_kws.setdefault("warn_singular", False)
# -> 2148         grid.map_diag(kdeplot, **diag_kws)
#    2149
#    2150     # Maybe plot on the off-diagonals
#
# ...
